# %%
import sys
import numpy as np
from datascience import *
import math 
# These lines set up the plotting functionality and formatting.
import matplotlib
matplotlib.use('Agg', warn=False)
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
#this cell sets up measures of inflation by year, quarter, and month
cpiY = Table().read_table("CPI.csv").relabeled(1, "CPI")
cpiYs = cpiY.column("CPI")
piY = np.diff(cpiYs)/(cpiYs[:len(cpiYs) - 1])

cpiQ = Table().read_table("quarterlyCPI.csv").relabeled(1, "CPI")
cpiQs = cpiQ.column("CPI")
piQ = np.diff(cpiQs)/(cpiQs[:len(cpiQs) - 1])

cpiM = Table().read_table("monthlyCPI.csv").relabeled(1, "CPI")
cpiMs = cpiM.column("CPI")
piM = np.diff(cpiMs)/(cpiMs[:len(cpiMs) - 1])

inflation_by_year = Table().with_columns("DATE", np.arange(1947, 2016), "INFLATION RATE", piY)
inflation_by_quarter = Table().with_columns("DATE", cpiQ.column(0)[:len(piQ)], "INFLATION RATE", piQ)
inflation_by_month = Table().with_columns("DATE", cpiM.column(0)[:len(piM)], "INFLATION RATE", piM)
inflation_by_month = inflation_by_month.with_column("DATE", [x[:len(x) - 3] for x in inflation_by_month.column("DATE")]).where("INFLATION RATE", are.between(-.01, .02))

# %%
#this cell sets up the rest of the data
r = Table().read_table("r*.csv").select("TIME", "Value").relabeled("TIME", "DATE").relabeled("Value", "r")

unemployment = Table().read_table("unemployment.csv").relabeled(1, "UNEMPLOYMENT RATE")

y_pop = Table().read_table("Y*.csv").relabeled(1, "POTENTIAL GDP")

y = Table().read_table("Y.csv").relabeled(1, "GDP")

gdp = y.join("DATE", y_pop)

distress = Table().read_table("distress.csv").relabeled(1, "ECONOMIC CONDITION")
new_distress = []
for num in distress.column(1):
    if num < 60:
        new_distress.append("Emergency")
    elif num < 70:
        new_distress.append("Distressed")
    elif num < 80:
        new_distress.append("At-Risk")
    elif num < 60:
        new_distress.append("Good")
    else:
        new_distress.append("Excellent")
distress = distress.with_column("ECONOMIC CONDITION", new_distress)

# %% [markdown]
# ## Quarterly Data from 1949 to Present

# %% [markdown]
# The table below contains real GDP, real potential GDP, unemployment rate, inflation rate, and level below potential per quarter.
# GDP is defined as the market value of the final goods and services newly produced in a country during some period of time, adjusted for price changes. Potential GDP is this measure of output given by long-run economic variables such as capital, technology, amd employment at normal economic times (not in a recession/boom).

# %%
quarterly_data = gdp.join("DATE", unemployment).join("DATE", inflation_by_quarter)
quarterly_data = quarterly_data.with_column("OUTPUT MINUS POTENTIAL", quarterly_data.column(1) - quarterly_data.column(2)).with_column("DATE", [x[:len(x) - 3] for x in quarterly_data.column(0)])
quarterly_data
# Out:
# DATE    | GDP    | POTENTIAL GDP | UNEMPLOYMENT RATE | INFLATION RATE | OUTPUT MINUS POTENTIAL
# 1949-01 | 2007.5 | 2011.3        | 4.3               | -0.00108591    | -3.8
# 1949-04 | 2000.8 | 2038.1        | 5.3               | -0.00836225    | -37.3
# 1949-07 | 2022.8 | 2065.2        | 6.7               | -0.00240334    | -42.4
# 1949-10 | 2004.7 | 2092.6        | 7.9               | -0.00308538    | -87.9
# 1950-01 | 2084.6 | 2120.1        | 6.5               | 0.00763132     | -35.5
# 1950-04 | 2147.6 | 2147.2        | 5.8               | 0.0183448      | 0.4
# 1950-07 | 2230.4 | 2174.7        | 5                 | 0.0202454      | 55.7
# 1950-10 | 2273.4 | 2202.5        | 4.2               | 0.0406593      | 70.9
# 1951-01 | 2304.5 | 2230.8        | 3.7               | 0.00972876     | 73.7
# 1951-04 | 2344.5 | 2260.7        | 3.1               | -0.000539561   | 83.8
# ... (262 rows omitted)

# %% [markdown]
# ** The economy is in a recession when real GDP (output adjusted for inflation) is below the economy's potential. We can see this effect below. **

# %%
distress = distress.with_column("DATE", [x[:len(x) - 3] for x in distress.column("DATE")]).join("DATE", quarterly_data)
distress.group("ECONOMIC CONDITION", np.mean).relabeled("UNEMPLOYMENT RATE mean", "AVERAGE UNEMPLOYMENT RATE").sort("AVERAGE UNEMPLOYMENT RATE", descending = True).barh("ECONOMIC CONDITION", "AVERAGE UNEMPLOYMENT RATE")
distress.group("ECONOMIC CONDITION", np.mean).sort("OUTPUT MINUS POTENTIAL mean", descending = True).relabeled("OUTPUT MINUS POTENTIAL mean", "AVERAGE DIFFERENCE BETWEEN OUTPUT AND POTENTIAL").barh("ECONOMIC CONDITION", "AVERAGE DIFFERENCE BETWEEN OUTPUT AND POTENTIAL")

# %% [markdown]
# ## The Great Recession

# %% [markdown]
# ** Now we know that when output falls below potential, the economy is in worse shape (a condition reinforced by unemployment rate). We can see the U.S. economy's condition over time changing between 2000 and 2018 below.**

# %%
quarterly_w_time = quarterly_data.select("UNEMPLOYMENT RATE", "OUTPUT MINUS POTENTIAL").with_column("DATE", [int(x[:len(x) - 3]) + int(x[len(x) - 2:])/12 for x in quarterly_data.column("DATE")])
recession_line_data = quarterly_w_time.with_column("OUTPUT MINUS POTENTIAL", quarterly_w_time.column("OUTPUT MINUS POTENTIAL") / 100).relabeled("UNEMPLOYMENT RATE", "%Unemployment").relabeled("OUTPUT MINUS POTENTIAL", "Level Below Potential Output(10^11$))")
recession_line_data = recession_line_data.where("DATE", are.between(2000, 2018))
recession_line_data.plot("DATE", width = 30, height = 18)

# %% [markdown]
# **Perumutation Test**
# Run a permutation test on output - potential vs economic condition

# %%
"""
A list of recessions in the U.S. as per 
https://en.wikipedia.org/wiki/List_of_recessions_in_the_United_States

Each entry is of the format ((Year Start, Month Start), (Year End, Month End))
"""
recession_list = [((1948, 11),(1949,10)), ((1953, 7),(1954,5)), 
                  ((1957, 8),(1958,4)), ((1960, 4),(1961,2)),
                  ((1969, 12),(1970,11)), ((1973, 11),(1975,3)),
                  ((1980, 1),(1980,7)), ((1981, 7),(1982,11)),
                  ((1990, 7),(1991,3)), ((2001, 3),(2001,11)),
                  ((2007, 12),(2009,6))
                 ]

def isRecession(date):
    """Given a date of str format 'Year-Month'
    determines if the date is within a span of a recession
    
    Implemented using binary search
    """
    dateInt = int(date[0:4])*100 + int(date[5:])
    left, right=  0, len(recession_list)-1
    while(left <= right):
        mid = (right+left)//2
        testRange = recession_list[mid]
        leftInt = testRange[0][0]*100 + testRange[0][1]
        rightInt = testRange[1][0]*100 + testRange[1][1]
        if(dateInt >= leftInt and dateInt <= rightInt):
            return True
        if(dateInt < leftInt):
            right = mid-1
        else:
            left = mid+1
    return False
    

quarterly_data_rec = quarterly_data.with_column("In Recession", quarterly_data.apply(isRecession, 'DATE'))
quarterly_data_rec
# Out:
# DATE    | GDP    | POTENTIAL GDP | UNEMPLOYMENT RATE | INFLATION RATE | OUTPUT MINUS POTENTIAL | In Recession
# 1949-01 | 2007.5 | 2011.3        | 4.3               | -0.00108591    | -3.8                   | True
# 1949-04 | 2000.8 | 2038.1        | 5.3               | -0.00836225    | -37.3                  | True
# 1949-07 | 2022.8 | 2065.2        | 6.7               | -0.00240334    | -42.4                  | True
# 1949-10 | 2004.7 | 2092.6        | 7.9               | -0.00308538    | -87.9                  | True
# 1950-01 | 2084.6 | 2120.1        | 6.5               | 0.00763132     | -35.5                  | False
# 1950-04 | 2147.6 | 2147.2        | 5.8               | 0.0183448      | 0.4                    | False
# 1950-07 | 2230.4 | 2174.7        | 5                 | 0.0202454      | 55.7                   | False
# 1950-10 | 2273.4 | 2202.5        | 4.2               | 0.0406593      | 70.9                   | False
# 1951-01 | 2304.5 | 2230.8        | 3.7               | 0.00972876     | 73.7                   | False
# 1951-04 | 2344.5 | 2260.7        | 3.1               | -0.000539561   | 83.8                   | False
# ... (262 rows omitted)

# %% [markdown]
# ** Null Hypothesis: ** In the population, whether the economy is in a recession and output level relative to potential output are independent of each other. The average output minus potential is inherently the same regardless; the low level during the Great Recession is only due to chance.
#
# ** Alternative Hypothesis: ** The two distributions (recessionary, non-recessionary) are different in the population.
#
# ** Significance Level: ** $\alpha = .05$
#
# ** Test Statistic: ** Absolute difference between the average of output minus potential during times of recession and otherwise.

# %%
def difference_in_means(t):
    means = t.group(0, np.mean)
    return means.column(1).item(0) - means.column(1).item(1)

# %%
t = quarterly_data_rec.select("In Recession", "OUTPUT MINUS POTENTIAL")
observed = abs(difference_in_means(t))
stats = make_array()
means_diffs = make_array()
for i in np.arange(10000):
    shuffled_var = t.select("OUTPUT MINUS POTENTIAL").sample(with_replacement=False).column(0)
    shuffled = t.select("In Recession").with_column('Shuffled Variable', shuffled_var)
    new_stat = abs(difference_in_means(shuffled))
    stats = np.append(stats, new_stat)

p = np.count_nonzero(stats >= observed) / 10000

Table().with_column('Difference Between Means', stats).hist()
plots.title('Empirical Distribution Under the Null')
print('Average difference between actual and potential output at recession vs not:', observed)
print('Empirical P-value:', p)
# Out:
# Average difference between actual and potential output at recession vs not: 91.89706314243764
# Empirical P-value: 0.0078

# %% [markdown]
# The p-value is far less than the determined significance level of 5%; therefore we will **reject the null** that  whether the economy is in a recession and output level relative to potential output are independent of each other.

# %%
"""Bootstrap approximate 95% confidence interval
for the difference between the means of the two 
classes in the population"""
    
stats = make_array()
for i in np.arange(10000):
    bootstrap_sample = t.sample()
    new_stat = difference_in_means(bootstrap_sample)
    stats = np.append(stats, new_stat)
        
left = percentile(2.5, stats)
right = percentile(97.5, stats)
    
Table().with_column('Difference Between Means', stats).hist()
plots.plot(make_array(left, right), make_array(0, 0), color='yellow', lw=8)
print('Approximate 95% CI for the difference between means:')
print(left, 'to', right)
# Out:
# Approximate 95% CI for the difference between means:
# 26.6374764595 to 161.191347687

# %% [markdown]
# ## The Fed's Reaction Function

# %% [markdown]
# We know that the Federal Reserve tends to adjust the real interest rate according to the inflation rate as a part of countercyclical monetary policy. When output is below potential, the inflation rate falls because firms are operating below their level of comfort, so they must lower prices. To counteract this, the Fed will engage in open market operations to bring output back to potential. By selling government bonds, it can increase the money supply and lower interest rates. Therefore, people will consume more as will firms invest more, bringing output back to potential. The Fed can set a target inflation rate by defining how they change the real interest rate in response to changes in inflation; this is called the *reaction function*.

# %%
fed_reaction_function = inflation_by_month.join("DATE", r)
fed_reaction_function.scatter("INFLATION RATE", "r", fit_line = True)

# %%
def standard_units(any_numbers):
    "Convert any array of numbers to standard units."
    return (any_numbers - np.mean(any_numbers)) / np.std(any_numbers)  

def standardize(t):
    """Return a table in which all columns of t are converted to standard units."""
    t_su = Table()
    for label in t.labels:
        t_su = t_su.with_column(label + ' (su)', standard_units(t.column(label)))
    return t_su

def correlation(t, x, y):
    """Return the correlation coefficient (r) of two variables."""
    return np.mean(standard_units(t.column(x)) * standard_units(t.column(y)))

# %%
def slope(t, x, y):
    """The slope of ther regression line (original units)."""
    r = correlation(t, x, y)
    return r * np.std(t.column(y)) / np.std(t.column(x))

def intercept(t, x, y):
    """The intercept of the regression line (original units)."""
    return np.mean(t.column(y)) - slope(t, x, y) * np.mean(t.column(x))

# %% [markdown]
# DRAW THE RESIDUAL PLOT AND EVALUATE HOW APPROPRIATE IT WAS TO USE REGRESSION

# %%
line_slope = slope(fed_reaction_function, "INFLATION RATE", "r")
line_intercept = intercept(fed_reaction_function, "INFLATION RATE", "r")
estimates = fed_reaction_function.column("INFLATION RATE")*line_slope + line_intercept
fed_react_resid = Table().with_columns("INFLATION RATE", fed_reaction_function.column("INFLATION RATE"), "r Residual", fed_reaction_function.column("r") - estimates )
fed_react_resid.scatter("INFLATION RATE", fit_line = True)

# %% [markdown]
# From the residual plot, it is clear that Linear Least-Squares Regression is not a very applicable form of estimation.

# %%
correlation(fed_reaction_function, "INFLATION RATE", "r")
# Out:
# 0.46141756527147193

# %%
inflation = fed_reaction_function.column("INFLATION RATE")
real_interest = fed_reaction_function.column("r")
pol = np.poly1d(np.polyfit(inflation, real_interest, deg = 2 ))

# %%
quad_fed_react = fed_reaction_function.select("INFLATION RATE", "r").with_column("r Quadratic Estimation", pol(fed_reaction_function.column("INFLATION RATE")))
quad_fed_react.scatter("INFLATION RATE", overlay = True)

# %% [markdown]
# Ok, so clearly Quadratic Least Squares is not a good fit either. After trying higher degree polynomials, it is clear that any polynomial Least Squares prediction will not work.
#
# predict the output - potential output for a quarter given the output-potential, inflation rate, and unemployment rate of the previous 40 quarters.
# Input vector shape => [?, 120]
# Output vector shape => [?, 1]

# %%
import tensorflow as tf

# %%
num_features = 120
num_out = 1
num_it = 10000
quarterly_data
# Out:
# DATE    | GDP    | POTENTIAL GDP | UNEMPLOYMENT RATE | INFLATION RATE | OUTPUT MINUS POTENTIAL
# 1949-01 | 2007.5 | 2011.3        | 4.3               | -0.00108591    | -3.8
# 1949-04 | 2000.8 | 2038.1        | 5.3               | -0.00836225    | -37.3
# 1949-07 | 2022.8 | 2065.2        | 6.7               | -0.00240334    | -42.4
# 1949-10 | 2004.7 | 2092.6        | 7.9               | -0.00308538    | -87.9
# 1950-01 | 2084.6 | 2120.1        | 6.5               | 0.00763132     | -35.5
# 1950-04 | 2147.6 | 2147.2        | 5.8               | 0.0183448      | 0.4
# 1950-07 | 2230.4 | 2174.7        | 5                 | 0.0202454      | 55.7
# 1950-10 | 2273.4 | 2202.5        | 4.2               | 0.0406593      | 70.9
# 1951-01 | 2304.5 | 2230.8        | 3.7               | 0.00972876     | 73.7
# 1951-04 | 2344.5 | 2260.7        | 3.1               | -0.000539561   | 83.8
# ... (262 rows omitted)

# %%
ind = 40
trainX = np.array(np.zeros(120))
trainY = np.array(np.zeros(1))
allX = np.array(np.zeros(120))
allY = np.array(np.zeros(1))
while (ind < quarterly_data.num_rows):
    temp = np.array([])
    for i in range(ind-40, ind):
        row = np.array(quarterly_data.row(i))
        temp = np.append(temp, [float(row[3]), float(row[4]), float(row[5])])
    allX = np.vstack((allX, np.array(temp)))
    allY = np.vstack((allY, np.array(np.array(float(np.array(quarterly_data.row(ind))[5])))))
    if(ind < quarterly_data.num_rows-(4*20)):
        trainX = np.vstack((trainX, np.array(temp)))
        trainY = np.vstack((trainY, np.array(np.array(float(np.array(quarterly_data.row(ind))[5])))))
    ind+=1
trainX = trainX[1:,:]
trainY = trainY[1:, :]

# %%
x = tf.placeholder(tf.float32, [None, num_features])

keep_prob = tf.placeholder(tf.float32)
drop1 = tf.nn.dropout(x, keep_prob)

W1 = tf.Variable(tf.truncated_normal([num_features, 50],
                                    stddev=1./math.sqrt(num_features)))
b1 = tf.Variable(tf.zeros([50]))
y1 = tf.nn.relu(tf.matmul(x, W1) + b1)

drop2 = tf.nn.dropout(y1, keep_prob)

W2 = tf.Variable(tf.truncated_normal([50, num_out],
                                    stddev=1./math.sqrt(num_features)))
b2 = tf.Variable(tf.zeros([num_out]))
y2 = tf.matmul(y1, W2) + b2

y_ = tf.placeholder(tf.float32, [None, num_out])
# cost = tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(y2), reduction_indices=[1])) #cross-entropy
cost = np.abs(y2-y_)
train_step = tf.train.AdamOptimizer(5e-3).minimize(cost)

# %%
sess = tf.InteractiveSession()

saver = tf.train.Saver()
correct_prediction = y2-y_
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
tf.global_variables_initializer().run()
saver = tf.train.Saver()

count = 0
max_train_acc = .926206
max_test_acc = .980658
test_acc = .5
train_acc = .5
while count < num_it:
    try:
        feed_dict = {x: trainX, y_: trainY, keep_prob: 0.5}
        example_data, train_acc = sess.run([train_step, accuracy], feed_dict)
    except tf.errors.OutOfRangeError:
        break
        
    print('training session', count,'\t|training accuracy', train_acc)
    count+=1
# Out:
# training session 0 	|training accuracy 74.0431
# training session 1 	|training accuracy 53.2832
# training session 2 	|training accuracy 33.2824
# training session 3 	|training accuracy 16.0615
# training session 4 	|training accuracy 3.39824
# training session 5 	|training accuracy -3.29052
# training session 6 	|training accuracy -5.43937
# training session 7 	|training accuracy -4.61558
# training session 8 	|training accuracy -2.59183
# training session 9 	|training accuracy -0.0633865
# training session 10 	|training accuracy 2.35568
# training session 11 	|training accuracy 4.67145
# training session 12 	|training accuracy 6.54091
# training session 13 	|training accuracy 7.11961
# training session 14 	|training accuracy 6.13507
# training session 15 	|training accuracy 4.20077
# training session 16 	|training accuracy 1.57976
# training session 17 	|training accuracy -1.89746
# training session 18 	|training accuracy -4.54025
# training session 19 	|training accuracy -4.70035
# training session 20 	|training accuracy -2.29213
# training session 21 	|training accuracy 1.71002
# training session 22 	|training accuracy 5.90619
# training session 23 	|training accuracy 8.9856
# training session 24 	|training accuracy 9.70631
# training session 25 	|training accuracy 8.30911
# training session 26 	|training accuracy 5.61592
# training session 27 	|training accuracy 2.5496
# training session 28 	|training accuracy 0.198781
# training session 29 	|training accuracy -1.00461
# training session 30 	|training accuracy -1.3674
# training session 31 	|training accuracy -1.5893
# training session 32 	|training accuracy -0.984204
# training session 33 	|training accuracy 0.770932
# training session 34 	|training accuracy 2.92512
# training session 35 	|training accuracy 3.76611
# training session 36 	|training accuracy 3.44024
# training session 37 	|training accuracy 2.00531
# training session 38 	|training accuracy 0.841684
# training session 39 	|training accuracy 0.145926
# training session 40 	|training accuracy -0.432828
# training session 41 	|training accuracy -0.176485
# training session 42 	|training accuracy -0.720554
# training session 43 	|training accuracy -1.5074
# training session 44 	|training accuracy -0.549354
# training session 45 	|training accuracy 1.03377
# training session 46 	|training accuracy 0.160714
# training session 47 	|training accuracy -1.74799
# training session 48 	|training accuracy -0.233652
# training session 49 	|training accuracy -0.106705
# training session 50 	|training accuracy -1.04444
# training session 51 	|training accuracy -0.967529
# training session 52 	|training accuracy -1.23566
# training session 53 	|training accuracy -1.12471
# training session 54 	|training accuracy -0.356529
# training session 55 	|training accuracy 0.109565
# training session 56 	|training accuracy 0.94615
# training session 57 	|training accuracy -0.114411
# training session 58 	|training accuracy 0.354884
# training session 59 	|training accuracy 0.00611463
# training session 60 	|training accuracy 1.43575
# training session 61 	|training accuracy -2.34417
# training session 62 	|training accuracy 0.937412
# training session 63 	|training accuracy 0.934016
# training session 64 	|training accuracy -2.66354
# training session 65 	|training accuracy 0.289664
# training session 66 	|training accuracy 0.97308
# training session 67 	|training accuracy -1.88223
# training session 68 	|training accuracy -0.197888
# training session 69 	|training accuracy 0.966857
# training session 70 	|training accuracy -1.49535
# training session 71 	|training accuracy -0.115109
# training session 72 	|training accuracy 2.5528
# training session 73 	|training accuracy 3.29505
# training session 74 	|training accuracy -0.286067
# training session 75 	|training accuracy 0.569798
# training session 76 	|training accuracy 0.470537
# training session 77 	|training accuracy -0.542984
# training session 78 	|training accuracy 0.781626
# training session 79 	|training accuracy 1.03228
# training session 80 	|training accuracy -0.298365
# training session 81 	|training accuracy 0.327735
# training session 82 	|training accuracy -1.61978
# training session 83 	|training accuracy -0.0624162
# training session 84 	|training accuracy 1.78141
# training session 85 	|training accuracy -0.0102808
# training session 86 	|training accuracy 0.381573
# training session 87 	|training accuracy 1.2946
# training session 88 	|training accuracy -1.98784
# training session 89 	|training accuracy 1.34353
# training session 90 	|training accuracy -0.125516
# training session 91 	|training accuracy -1.7408
# training session 92 	|training accuracy 1.74046
# training session 93 	|training accuracy -0.432461
# training session 94 	|training accuracy -1.67288
# training session 95 	|training accuracy 2.19055
# training session 96 	|training accuracy 0.166532
# training session 97 	|training accuracy -1.33753
# training session 98 	|training accuracy 1.44961
# training session 99 	|training accuracy 0.160148
# training session 100 	|training accuracy -1.25423
# training session 101 	|training accuracy 1.97984
# training session 102 	|training accuracy 1.41563
# training session 103 	|training accuracy -1.60231
# training session 104 	|training accuracy -0.0353744
# training session 105 	|training accuracy 0.575099
# training session 106 	|training accuracy -2.64485
# training session 107 	|training accuracy -0.43941
# training session 108 	|training accuracy 1.96323
# training session 109 	|training accuracy -2.16612
# training session 110 	|training accuracy -1.37669
# training session 111 	|training accuracy 3.00813
# training session 112 	|training accuracy 0.222844
# training session 113 	|training accuracy -3.80811
# training session 114 	|training accuracy -0.318864
# training session 115 	|training accuracy 2.26346
# training session 116 	|training accuracy -1.37793
# training session 117 	|training accuracy -2.09513
# training session 118 	|training accuracy 3.47729
# training session 119 	|training accuracy 1.74966
# training session 120 	|training accuracy -4.24099
# training session 121 	|training accuracy -0.813351
# training session 122 	|training accuracy 3.64577
# training session 123 	|training accuracy -0.336326
# training session 124 	|training accuracy -3.79622
# training session 125 	|training accuracy 0.687322
# training session 126 	|training accuracy 0.695186
# training session 127 	|training accuracy -2.4368
# training session 128 	|training accuracy 0.193025
# training session 129 	|training accuracy 0.222715
# training session 130 	|training accuracy -0.967334
# training session 131 	|training accuracy 0.338536
# training session 132 	|training accuracy 0.531983
# training session 133 	|training accuracy -3.72562
# training session 134 	|training accuracy -1.23122
# training session 135 	|training accuracy 3.28765
# training session 136 	|training accuracy -0.822777
# training session 137 	|training accuracy -1.11801
# training session 138 	|training accuracy -0.269295
# training session 139 	|training accuracy 0.828343
# training session 140 	|training accuracy -0.587056
# training session 141 	|training accuracy -0.948041
# training session 142 	|training accuracy -1.22634
# training session 143 	|training accuracy 0.718498
# training session 144 	|training accuracy 0.392023
# training session 145 	|training accuracy -0.466074
# training session 146 	|training accuracy -1.33867
# training session 147 	|training accuracy 0.910128
# training session 148 	|training accuracy -0.855713
# training session 149 	|training accuracy -1.28836
# training session 150 	|training accuracy 1.67339
# training session 151 	|training accuracy -0.674406
# training session 152 	|training accuracy -2.58799
# training session 153 	|training accuracy 1.23403
# training session 154 	|training accuracy -0.0249054
# training session 155 	|training accuracy -1.98053
# training session 156 	|training accuracy 1.22379
# training session 157 	|training accuracy 0.746976
# training session 158 	|training accuracy -2.1631
# training session 159 	|training accuracy -1.02682
# training session 160 	|training accuracy 1.79646
# training session 161 	|training accuracy 0.911245
# training session 162 	|training accuracy -0.623529
# training session 163 	|training accuracy 1.59288
# training session 164 	|training accuracy 2.76982
# training session 165 	|training accuracy -1.73715
# training session 166 	|training accuracy -5.34125
# training session 167 	|training accuracy 0.248411
# training session 168 	|training accuracy 4.05074
# training session 169 	|training accuracy -0.978956
# training session 170 	|training accuracy -3.4892
# training session 171 	|training accuracy 1.66585
# training session 172 	|training accuracy 3.46771
# training session 173 	|training accuracy -0.757355
# training session 174 	|training accuracy -2.3076
# training session 175 	|training accuracy 0.117115
# training session 176 	|training accuracy 0.90222
# training session 177 	|training accuracy 0.0294687
# training session 178 	|training accuracy -0.790297
# training session 179 	|training accuracy -1.11619
# training session 180 	|training accuracy 0.36212
# training session 181 	|training accuracy 1.54606
# training session 182 	|training accuracy -0.645438
# training session 183 	|training accuracy -1.18073
# training session 184 	|training accuracy 1.52607
# training session 185 	|training accuracy 0.0457877
# training session 186 	|training accuracy -1.09784
# training session 187 	|training accuracy 1.29676
# training session 188 	|training accuracy 0.245175
# training session 189 	|training accuracy -0.576106
# training session 190 	|training accuracy 1.2143
# training session 191 	|training accuracy 1.38986
# training session 192 	|training accuracy -3.10317
# training session 193 	|training accuracy -0.24718
# training session 194 	|training accuracy 2.43667
# training session 195 	|training accuracy 1.19105
# training session 196 	|training accuracy -0.457388
# training session 197 	|training accuracy -0.171877
# training session 198 	|training accuracy -0.389165
# training session 199 	|training accuracy -2.93468
# training session 200 	|training accuracy 0.967367
# training session 201 	|training accuracy 1.78012
# training session 202 	|training accuracy 0.845532
# training session 203 	|training accuracy -1.41517
# training session 204 	|training accuracy -1.14887
# training session 205 	|training accuracy 2.0376
# training session 206 	|training accuracy 1.08763
# training session 207 	|training accuracy -0.347416
# training session 208 	|training accuracy 0.393877
# training session 209 	|training accuracy 0.536416
# training session 210 	|training accuracy -1.1593
# training session 211 	|training accuracy 1.82502
# training session 212 	|training accuracy 1.39174
# training session 213 	|training accuracy -2.4167
# training session 214 	|training accuracy 0.336565
# training session 215 	|training accuracy 0.669087
# training session 216 	|training accuracy -1.52031
# training session 217 	|training accuracy 1.54343
# training session 218 	|training accuracy 0.757592
# training session 219 	|training accuracy -1.99972
# training session 220 	|training accuracy 0.444345
# training session 221 	|training accuracy 2.89343
# training session 222 	|training accuracy -0.71109
# training session 223 	|training accuracy -0.735521
# training session 224 	|training accuracy 1.63261
# training session 225 	|training accuracy 0.609521
# training session 226 	|training accuracy -1.32627
# training session 227 	|training accuracy -0.0331621
# training session 228 	|training accuracy 0.77696
# training session 229 	|training accuracy -1.35345
# training session 230 	|training accuracy -0.5593
# training session 231 	|training accuracy 2.52267
# training session 232 	|training accuracy 0.826533
# training session 233 	|training accuracy -0.0799691
# training session 234 	|training accuracy 0.533634
# training session 235 	|training accuracy -0.512114
# training session 236 	|training accuracy -1.29451
# training session 237 	|training accuracy 2.06343
# training session 238 	|training accuracy 1.14861
# training session 239 	|training accuracy -0.625924
# training session 240 	|training accuracy -4.01257
# training session 241 	|training accuracy 1.89875
# training session 242 	|training accuracy 3.48526
# training session 243 	|training accuracy -2.89264
# training session 244 	|training accuracy -3.27242
# training session 245 	|training accuracy 1.96511
# training session 246 	|training accuracy 2.7146
# training session 247 	|training accuracy -2.01773
# training session 248 	|training accuracy -2.56974
# training session 249 	|training accuracy 3.06051
# training session 250 	|training accuracy 2.86554
# training session 251 	|training accuracy -1.11239
# training session 252 	|training accuracy -0.986029
# training session 253 	|training accuracy 3.39168
# training session 254 	|training accuracy 0.38362
# training session 255 	|training accuracy -4.17005
# training session 256 	|training accuracy -0.951468
# training session 257 	|training accuracy 4.54786
# training session 258 	|training accuracy 3.02742
# training session 259 	|training accuracy -1.5863
# training session 260 	|training accuracy -2.68861
# training session 261 	|training accuracy 0.913988
# training session 262 	|training accuracy -0.307012
# training session 263 	|training accuracy -1.59162
# training session 264 	|training accuracy 2.21457
# training session 265 	|training accuracy 3.03278
# training session 266 	|training accuracy -2.22689
# training session 267 	|training accuracy -2.18383
# training session 268 	|training accuracy 0.979709
# training session 269 	|training accuracy 0.0141433
# training session 270 	|training accuracy 0.786738
# training session 271 	|training accuracy 0.125194
# training session 272 	|training accuracy -1.55628
# training session 273 	|training accuracy 0.128155
# training session 274 	|training accuracy 3.16867
# training session 275 	|training accuracy -1.35753
# training session 276 	|training accuracy -1.58183
# training session 277 	|training accuracy 2.12453
# training session 278 	|training accuracy 0.964253
# training session 279 	|training accuracy -1.10222
# training session 280 	|training accuracy -0.290316
# training session 281 	|training accuracy 1.45926
# training session 282 	|training accuracy -0.0019696
# training session 283 	|training accuracy -1.6078
# training session 284 	|training accuracy 0.400426
# training session 285 	|training accuracy 0.37539
# training session 286 	|training accuracy 0.554898
# training session 287 	|training accuracy 0.674763
# training session 288 	|training accuracy -0.0377314
# training session 289 	|training accuracy 0.63736
# training session 290 	|training accuracy 0.312173
# training session 291 	|training accuracy -1.21983
# training session 292 	|training accuracy 1.16596
# training session 293 	|training accuracy 0.0561233
# training session 294 	|training accuracy -1.71494
# training session 295 	|training accuracy 1.4723
# training session 296 	|training accuracy 1.70793
# training session 297 	|training accuracy -1.33862
# training session 298 	|training accuracy -0.758539
# training session 299 	|training accuracy 3.06542
# training session 300 	|training accuracy 1.85812
# training session 301 	|training accuracy -2.59832
# training session 302 	|training accuracy -1.34783
# training session 303 	|training accuracy 1.64806
# training session 304 	|training accuracy 1.29348
# training session 305 	|training accuracy -1.35869
# training session 306 	|training accuracy -0.671933
# training session 307 	|training accuracy 3.2153
# training session 308 	|training accuracy 3.36378
# training session 309 	|training accuracy -1.06451
# training session 310 	|training accuracy -1.68489
# training session 311 	|training accuracy 2.9663
# training session 312 	|training accuracy 2.20706
# training session 313 	|training accuracy -2.70566
# training session 314 	|training accuracy -2.43474
# training session 315 	|training accuracy 3.55615
# training session 316 	|training accuracy 4.09635
# training session 317 	|training accuracy -1.78998
# training session 318 	|training accuracy -2.67615
# training session 319 	|training accuracy 2.84635
# training session 320 	|training accuracy 2.19623
# training session 321 	|training accuracy -2.37773
# training session 322 	|training accuracy -1.07605
# training session 323 	|training accuracy 3.3803
# training session 324 	|training accuracy 1.74972
# training session 325 	|training accuracy -2.363
# training session 326 	|training accuracy -1.35098
# training session 327 	|training accuracy 1.82533
# training session 328 	|training accuracy 0.656015
# training session 329 	|training accuracy -0.962446
# training session 330 	|training accuracy -0.168978
# training session 331 	|training accuracy 0.165748
# training session 332 	|training accuracy 0.197146
# training session 333 	|training accuracy 0.399678
# training session 334 	|training accuracy 0.823207
# training session 335 	|training accuracy -0.984969
# training session 336 	|training accuracy -0.209719
# training session 337 	|training accuracy 1.14557
# training session 338 	|training accuracy 1.03015
# training session 339 	|training accuracy 0.712393
# training session 340 	|training accuracy -0.147633
# training session 341 	|training accuracy -0.897742
# training session 342 	|training accuracy -0.184041
# training session 343 	|training accuracy 1.48819
# training session 344 	|training accuracy 0.847372
# training session 345 	|training accuracy -0.188807
# training session 346 	|training accuracy -0.752831
# training session 347 	|training accuracy 1.03865
# training session 348 	|training accuracy 0.0904591
# training session 349 	|training accuracy 0.171499
# training session 350 	|training accuracy 1.06778
# training session 351 	|training accuracy -0.313919
# training session 352 	|training accuracy -0.0120272
# training session 353 	|training accuracy 2.35724
# training session 354 	|training accuracy 1.22853
# training session 355 	|training accuracy -1.89512
# training session 356 	|training accuracy -0.6649
# training session 357 	|training accuracy 3.27469
# training session 358 	|training accuracy 3.80327
# training session 359 	|training accuracy -1.53594
# training session 360 	|training accuracy -3.108
# training session 361 	|training accuracy 2.22488
# training session 362 	|training accuracy 2.93617
# training session 363 	|training accuracy -0.4841
# training session 364 	|training accuracy -2.33642
# training session 365 	|training accuracy 1.21023
# training session 366 	|training accuracy 2.45671
# training session 367 	|training accuracy 0.290135
# training session 368 	|training accuracy 0.324567
# training session 369 	|training accuracy 1.80717
# training session 370 	|training accuracy 0.245415
# training session 371 	|training accuracy -1.77164
# training session 372 	|training accuracy 0.610464
# training session 373 	|training accuracy 2.69366
# training session 374 	|training accuracy -0.665715
# training session 375 	|training accuracy -2.92844
# training session 376 	|training accuracy 0.919838
# training session 377 	|training accuracy 3.16307
# training session 378 	|training accuracy 0.0295481
# training session 379 	|training accuracy -1.35127
# training session 380 	|training accuracy 2.20286
# training session 381 	|training accuracy 2.63783
# training session 382 	|training accuracy 0.0779091
# training session 383 	|training accuracy -0.939754
# training session 384 	|training accuracy 1.70262
# training session 385 	|training accuracy 0.420493
# training session 386 	|training accuracy -2.50624
# training session 387 	|training accuracy -0.426082
# training session 388 	|training accuracy 2.52377
# training session 389 	|training accuracy 0.67998
# training session 390 	|training accuracy -1.99773
# training session 391 	|training accuracy -0.599804
# training session 392 	|training accuracy 2.61187
# training session 393 	|training accuracy 1.51059
# training session 394 	|training accuracy -1.33601
# training session 395 	|training accuracy -0.431833
# training session 396 	|training accuracy 3.16298
# training session 397 	|training accuracy 1.15087
# training session 398 	|training accuracy -2.22583
# training session 399 	|training accuracy 0.204558
# training session 400 	|training accuracy 3.46117
# training session 401 	|training accuracy 1.60971
# training session 402 	|training accuracy -3.70239
# training session 403 	|training accuracy -3.41052
# training session 404 	|training accuracy 1.38295
# training session 405 	|training accuracy 3.22218
# training session 406 	|training accuracy 0.543072
# training session 407 	|training accuracy -1.64376
# training session 408 	|training accuracy 0.691805
# training session 409 	|training accuracy 1.97247
# training session 410 	|training accuracy -1.11774
# training session 411 	|training accuracy -1.02853
# training session 412 	|training accuracy 0.902645
# training session 413 	|training accuracy 1.18328
# training session 414 	|training accuracy -1.19715
# training session 415 	|training accuracy 1.1118
# training session 416 	|training accuracy 1.41156
# training session 417 	|training accuracy 0.206299
# training session 418 	|training accuracy 0.896586
# training session 419 	|training accuracy -0.672005
# training session 420 	|training accuracy 0.300091
# training session 421 	|training accuracy 2.29048
# training session 422 	|training accuracy -1.24742
# training session 423 	|training accuracy -0.0593926
# training session 424 	|training accuracy 1.83848
# training session 425 	|training accuracy -0.206681
# training session 426 	|training accuracy -1.49444
# training session 427 	|training accuracy 1.52856
# training session 428 	|training accuracy 2.27762
# training session 429 	|training accuracy -1.08646
# training session 430 	|training accuracy -0.287695
# training session 431 	|training accuracy 0.817735
# training session 432 	|training accuracy -0.474314
# training session 433 	|training accuracy 0.129618
# training session 434 	|training accuracy 1.15061
# training session 435 	|training accuracy -0.358285
# training session 436 	|training accuracy 0.00541009
# training session 437 	|training accuracy 1.31743
# training session 438 	|training accuracy -0.141307
# training session 439 	|training accuracy -1.44833
# training session 440 	|training accuracy 1.05837
# training session 441 	|training accuracy 3.47639
# training session 442 	|training accuracy 0.59492
# training session 443 	|training accuracy -1.98611
# training session 444 	|training accuracy 0.597377
# training session 445 	|training accuracy 3.51065
# training session 446 	|training accuracy 0.748036
# training session 447 	|training accuracy -3.87711
# training session 448 	|training accuracy -2.01912
# training session 449 	|training accuracy 3.70363
# training session 450 	|training accuracy 3.09667
# training session 451 	|training accuracy -1.02998
# training session 452 	|training accuracy -2.10473
# training session 453 	|training accuracy 0.883248
# training session 454 	|training accuracy 3.17459
# training session 455 	|training accuracy 0.676802
# training session 456 	|training accuracy -3.32245
# training session 457 	|training accuracy -2.03254
# training session 458 	|training accuracy 2.27165
# training session 459 	|training accuracy 2.37792
# training session 460 	|training accuracy 0.000444538
# training session 461 	|training accuracy -1.60861
# training session 462 	|training accuracy 0.247277
# training session 463 	|training accuracy 2.15078
# training session 464 	|training accuracy 0.177915
# training session 465 	|training accuracy -1.47533
# training session 466 	|training accuracy 1.04092
# training session 467 	|training accuracy 2.70224
# training session 468 	|training accuracy -0.429608
# training session 469 	|training accuracy -3.95901
# training session 470 	|training accuracy -2.21692
# training session 471 	|training accuracy 2.10579
# training session 472 	|training accuracy 1.82209
# training session 473 	|training accuracy -1.1839
# training session 474 	|training accuracy -1.70078
# training session 475 	|training accuracy 2.76303
# training session 476 	|training accuracy 2.69794
# training session 477 	|training accuracy -0.463769
# training session 478 	|training accuracy -0.789034
# training session 479 	|training accuracy 0.389669
# training session 480 	|training accuracy 1.69706
# training session 481 	|training accuracy 0.122379
# training session 482 	|training accuracy -0.127512
# training session 483 	|training accuracy -0.387832
# training session 484 	|training accuracy 1.01141
# training session 485 	|training accuracy 0.872371
# training session 486 	|training accuracy -0.266934
# training session 487 	|training accuracy -0.70231
# training session 488 	|training accuracy 1.16759
# training session 489 	|training accuracy 0.366167
# training session 490 	|training accuracy 0.0776204
# training session 491 	|training accuracy 0.347895
# training session 492 	|training accuracy 1.60455
# training session 493 	|training accuracy -0.107084
# training session 494 	|training accuracy 0.244756
# training session 495 	|training accuracy 0.606544
# training session 496 	|training accuracy -0.0967659
# training session 497 	|training accuracy -0.0778856
# training session 498 	|training accuracy 0.540081
# training session 499 	|training accuracy 0.825715
# training session 500 	|training accuracy 0.361055
# training session 501 	|training accuracy 1.16522
# training session 502 	|training accuracy -0.351936
# training session 503 	|training accuracy 0.350094
# training session 504 	|training accuracy 1.52388
# training session 505 	|training accuracy 0.0291366
# training session 506 	|training accuracy 0.422193
# training session 507 	|training accuracy 1.31714
# training session 508 	|training accuracy 1.47471
# training session 509 	|training accuracy -1.89851
# training session 510 	|training accuracy -1.59359
# training session 511 	|training accuracy 2.07114
# training session 512 	|training accuracy 0.948258
# training session 513 	|training accuracy -1.45889
# training session 514 	|training accuracy 0.830768
# training session 515 	|training accuracy 0.582399
# training session 516 	|training accuracy 0.286494
# training session 517 	|training accuracy -0.735524
# training session 518 	|training accuracy -0.302773
# training session 519 	|training accuracy 1.29893
# training session 520 	|training accuracy 1.17352
# training session 521 	|training accuracy -1.86324
# training session 522 	|training accuracy 0.473476
# training session 523 	|training accuracy 1.58511
# training session 524 	|training accuracy -0.559768
# training session 525 	|training accuracy 0.587022
# training session 526 	|training accuracy 0.992014
# training session 527 	|training accuracy -0.0769337
# training session 528 	|training accuracy 1.04239
# training session 529 	|training accuracy 0.245439
# training session 530 	|training accuracy -0.778595
# training session 531 	|training accuracy 1.57826
# training session 532 	|training accuracy 0.0808151
# training session 533 	|training accuracy -1.11919
# training session 534 	|training accuracy 2.07344
# training session 535 	|training accuracy 1.65787
# training session 536 	|training accuracy -2.31445
# training session 537 	|training accuracy -0.878269
# training session 538 	|training accuracy 1.98215
# training session 539 	|training accuracy 1.02392
# training session 540 	|training accuracy -0.621572
# training session 541 	|training accuracy 1.21412
# training session 542 	|training accuracy 0.702831
# training session 543 	|training accuracy -2.19198
# training session 544 	|training accuracy -0.784029
# training session 545 	|training accuracy 2.81211
# training session 546 	|training accuracy 1.36735
# training session 547 	|training accuracy -0.175557
# training session 548 	|training accuracy -0.202782
# training session 549 	|training accuracy -0.109378
# training session 550 	|training accuracy 0.690634
# training session 551 	|training accuracy 0.0677361
# training session 552 	|training accuracy 0.297203
# training session 553 	|training accuracy 1.37337
# training session 554 	|training accuracy -0.928254
# training session 555 	|training accuracy 0.486985
# training session 556 	|training accuracy 3.05256
# training session 557 	|training accuracy 0.977548
# training session 558 	|training accuracy -1.1127
# training session 559 	|training accuracy 0.428266
# training session 560 	|training accuracy -0.27751
# training session 561 	|training accuracy -1.37718
# training session 562 	|training accuracy 0.830359
# training session 563 	|training accuracy 1.90511
# training session 564 	|training accuracy 0.78207
# training session 565 	|training accuracy 0.582481
# training session 566 	|training accuracy 0.46959
# training session 567 	|training accuracy -0.586681
# training session 568 	|training accuracy 1.01205
# training session 569 	|training accuracy 1.22269
# training session 570 	|training accuracy -1.05795
# training session 571 	|training accuracy -0.186611
# training session 572 	|training accuracy 1.18575
# training session 573 	|training accuracy 0.619954
# training session 574 	|training accuracy -0.859948
# training session 575 	|training accuracy 1.56013
# training session 576 	|training accuracy 1.80046
# training session 577 	|training accuracy -1.96403
# training session 578 	|training accuracy -0.882516
# training session 579 	|training accuracy 2.48736
# training session 580 	|training accuracy 1.04673
# training session 581 	|training accuracy -1.68309
# training session 582 	|training accuracy -0.40216
# training session 583 	|training accuracy 1.69362
# training session 584 	|training accuracy 0.8037
# training session 585 	|training accuracy 1.75598
# training session 586 	|training accuracy 1.24695
# training session 587 	|training accuracy -0.980949
# training session 588 	|training accuracy -1.45479
# training session 589 	|training accuracy 1.12061
# training session 590 	|training accuracy 3.10383
# training session 591 	|training accuracy 0.280063
# training session 592 	|training accuracy -1.99404
# training session 593 	|training accuracy 0.934124
# training session 594 	|training accuracy 2.46081
# training session 595 	|training accuracy 1.27261
# training session 596 	|training accuracy -2.86752
# training session 597 	|training accuracy -0.709892
# training session 598 	|training accuracy 2.85702
# training session 599 	|training accuracy 0.66881
# training session 600 	|training accuracy -2.87294
# training session 601 	|training accuracy -0.125643
# training session 602 	|training accuracy 3.74806
# training session 603 	|training accuracy 1.69101
# training session 604 	|training accuracy -3.15821
# training session 605 	|training accuracy -1.97623
# training session 606 	|training accuracy 2.31741
# training session 607 	|training accuracy 2.30292
# training session 608 	|training accuracy -1.46588
# training session 609 	|training accuracy -1.77622
# training session 610 	|training accuracy 0.79804
# training session 611 	|training accuracy 1.63819
# training session 612 	|training accuracy -1.26973
# training session 613 	|training accuracy -1.18481
# training session 614 	|training accuracy 1.52627
# training session 615 	|training accuracy 2.24803
# training session 616 	|training accuracy -0.741291
# training session 617 	|training accuracy -1.535
# training session 618 	|training accuracy 1.18072
# training session 619 	|training accuracy 1.5536
# training session 620 	|training accuracy 0.0764171
# training session 621 	|training accuracy -0.209565
# training session 622 	|training accuracy 0.888591
# training session 623 	|training accuracy -0.00124837
# training session 624 	|training accuracy -0.357834
# training session 625 	|training accuracy 1.10409
# training session 626 	|training accuracy -0.43035
# training session 627 	|training accuracy 1.00397
# training session 628 	|training accuracy 0.559569
# training session 629 	|training accuracy -0.9945
# training session 630 	|training accuracy 0.551203
# training session 631 	|training accuracy 1.32695
# training session 632 	|training accuracy 0.195731
# training session 633 	|training accuracy -0.634178
# training session 634 	|training accuracy -0.000962697
# training session 635 	|training accuracy -0.430996
# training session 636 	|training accuracy 1.85529
# training session 637 	|training accuracy 2.37166
# training session 638 	|training accuracy -1.84781
# training session 639 	|training accuracy -2.80004
# training session 640 	|training accuracy 1.02699
# training session 641 	|training accuracy 3.01787
# training session 642 	|training accuracy 0.42329
# training session 643 	|training accuracy -2.54683
# training session 644 	|training accuracy 0.859847
# training session 645 	|training accuracy 3.67897
# training session 646 	|training accuracy 0.199893
# training session 647 	|training accuracy -1.73147
# training session 648 	|training accuracy -0.104028
# training session 649 	|training accuracy 1.15512
# training session 650 	|training accuracy 2.0743
# training session 651 	|training accuracy -0.125261
# training session 652 	|training accuracy -1.84245
# training session 653 	|training accuracy 0.945134
# training session 654 	|training accuracy 0.646496
# training session 655 	|training accuracy 0.00266242
# training session 656 	|training accuracy -0.861747
# training session 657 	|training accuracy 1.78245
# training session 658 	|training accuracy 0.0973162
# training session 659 	|training accuracy -1.07054
# training session 660 	|training accuracy 2.21165
# training session 661 	|training accuracy 1.08201
# training session 662 	|training accuracy -2.03265
# training session 663 	|training accuracy -0.717836
# training session 664 	|training accuracy 2.40272
# training session 665 	|training accuracy 0.551548
# training session 666 	|training accuracy -0.373794
# training session 667 	|training accuracy 1.19857
# training session 668 	|training accuracy 1.12503
# training session 669 	|training accuracy 0.831028
# training session 670 	|training accuracy 0.147275
# training session 671 	|training accuracy -0.417934
# training session 672 	|training accuracy 0.772714
# training session 673 	|training accuracy 0.468874
# training session 674 	|training accuracy -0.159505
# training session 675 	|training accuracy 0.415778
# training session 676 	|training accuracy 0.503971
# training session 677 	|training accuracy 0.477522
# training session 678 	|training accuracy -1.78514
# training session 679 	|training accuracy 0.908508
# training session 680 	|training accuracy 1.92275
# training session 681 	|training accuracy -1.1091
# training session 682 	|training accuracy -0.30769
# training session 683 	|training accuracy 1.92257
# training session 684 	|training accuracy -0.0698757
# training session 685 	|training accuracy 0.159148
# training session 686 	|training accuracy -0.711126
# training session 687 	|training accuracy 1.41046
# training session 688 	|training accuracy 0.770062
# training session 689 	|training accuracy -0.931713
# training session 690 	|training accuracy 1.01975
# training session 691 	|training accuracy 1.07782
# training session 692 	|training accuracy -1.46409
# training session 693 	|training accuracy 0.280331
# training session 694 	|training accuracy 1.35259
# training session 695 	|training accuracy -0.472478
# training session 696 	|training accuracy 0.0554582
# training session 697 	|training accuracy 1.66666
# training session 698 	|training accuracy -0.0253098
# training session 699 	|training accuracy -0.373745
# training session 700 	|training accuracy 0.579006
# training session 701 	|training accuracy 0.410528
# training session 702 	|training accuracy 0.97259
# training session 703 	|training accuracy -0.00109262
# training session 704 	|training accuracy -0.283771
# training session 705 	|training accuracy -0.794382
# training session 706 	|training accuracy 1.26879
# training session 707 	|training accuracy 0.611357
# training session 708 	|training accuracy 0.569442
# training session 709 	|training accuracy 1.89763
# training session 710 	|training accuracy -0.130641
# training session 711 	|training accuracy -2.61034
# training session 712 	|training accuracy -1.14518
# training session 713 	|training accuracy 2.86142
# training session 714 	|training accuracy 2.28467
# training session 715 	|training accuracy -0.911902
# training session 716 	|training accuracy -2.25007
# training session 717 	|training accuracy 0.462921
# training session 718 	|training accuracy 2.91803
# training session 719 	|training accuracy 0.881877
# training session 720 	|training accuracy -1.67706
# training session 721 	|training accuracy -0.326789
# training session 722 	|training accuracy 2.46261
# training session 723 	|training accuracy 2.04605
# training session 724 	|training accuracy -2.29377
# training session 725 	|training accuracy -2.50725
# training session 726 	|training accuracy 1.06135
# training session 727 	|training accuracy 2.93615
# training session 728 	|training accuracy 0.185005
# training session 729 	|training accuracy -2.44659
# training session 730 	|training accuracy -1.28256
# training session 731 	|training accuracy 3.06644
# training session 732 	|training accuracy 2.86525
# training session 733 	|training accuracy -0.316316
# training session 734 	|training accuracy -2.09256
# training session 735 	|training accuracy 0.0271707
# training session 736 	|training accuracy 1.94038
# training session 737 	|training accuracy 1.1972
# training session 738 	|training accuracy -2.23342
# training session 739 	|training accuracy -2.03668
# training session 740 	|training accuracy 0.974114
# training session 741 	|training accuracy 1.01085
# training session 742 	|training accuracy -1.03359
# training session 743 	|training accuracy 0.341251
# training session 744 	|training accuracy 2.35174
# training session 745 	|training accuracy 0.846303
# training session 746 	|training accuracy -2.34239
# training session 747 	|training accuracy -1.08177
# training session 748 	|training accuracy 3.19449
# training session 749 	|training accuracy 2.4373
# training session 750 	|training accuracy -2.69235
# training session 751 	|training accuracy -3.31536
# training session 752 	|training accuracy 0.926401
# training session 753 	|training accuracy 3.47815
# training session 754 	|training accuracy -0.073877
# training session 755 	|training accuracy -3.25855
# training session 756 	|training accuracy -1.21335
# training session 757 	|training accuracy 1.68523
# training session 758 	|training accuracy 0.844305
# training session 759 	|training accuracy -1.44612
# training session 760 	|training accuracy -0.73881
# training session 761 	|training accuracy 3.10528
# training session 762 	|training accuracy 3.94157
# training session 763 	|training accuracy 1.62864
# training session 764 	|training accuracy -2.27701
# training session 765 	|training accuracy -3.05042
# training session 766 	|training accuracy -0.351518
# training session 767 	|training accuracy 4.11626
# training session 768 	|training accuracy 4.73176
# training session 769 	|training accuracy 1.84066
# training session 770 	|training accuracy -2.29197
# training session 771 	|training accuracy -3.74096
# training session 772 	|training accuracy -0.862245
# training session 773 	|training accuracy 3.17098
# training session 774 	|training accuracy 4.14044
# training session 775 	|training accuracy 0.774249
# training session 776 	|training accuracy -3.0264
# training session 777 	|training accuracy -2.92133
# training session 778 	|training accuracy 2.05917
# training session 779 	|training accuracy 3.43591
# training session 780 	|training accuracy 0.118665
# training session 781 	|training accuracy -2.99507
# training session 782 	|training accuracy -0.808253
# training session 783 	|training accuracy 3.92216
# training session 784 	|training accuracy 3.46995
# training session 785 	|training accuracy -1.34371
# training session 786 	|training accuracy -3.77817
# training session 787 	|training accuracy -0.776267
# training session 788 	|training accuracy 4.11467
# training session 789 	|training accuracy 3.16285
# training session 790 	|training accuracy -1.95071
# training session 791 	|training accuracy -2.822
# training session 792 	|training accuracy 1.62778
# training session 793 	|training accuracy 4.29143
# training session 794 	|training accuracy 0.823397
# training session 795 	|training accuracy -3.29999
# training session 796 	|training accuracy -1.8855
# training session 797 	|training accuracy 2.30546
# training session 798 	|training accuracy 2.03541
# training session 799 	|training accuracy -0.921936
# training session 800 	|training accuracy -1.41142
# training session 801 	|training accuracy 1.07528
# training session 802 	|training accuracy 1.71517
# training session 803 	|training accuracy -1.50583
# training session 804 	|training accuracy -1.20517
# training session 805 	|training accuracy 0.958839
# training session 806 	|training accuracy -1.12135
# training session 807 	|training accuracy 0.0257817
# training session 808 	|training accuracy 1.99957
# training session 809 	|training accuracy 0.837444
# training session 810 	|training accuracy -1.34431
# training session 811 	|training accuracy -0.170801
# training session 812 	|training accuracy 2.2169
# training session 813 	|training accuracy 0.631912
# training session 814 	|training accuracy -2.0858
# training session 815 	|training accuracy -1.14423
# training session 816 	|training accuracy 2.33335
# training session 817 	|training accuracy 1.57658
# training session 818 	|training accuracy -2.07791
# training session 819 	|training accuracy -1.49894
# training session 820 	|training accuracy 3.36474
# training session 821 	|training accuracy 2.67654
# training session 822 	|training accuracy -1.52496
# training session 823 	|training accuracy -1.98621
# training session 824 	|training accuracy 1.38211
# training session 825 	|training accuracy 1.77857
# training session 826 	|training accuracy -1.33942
# training session 827 	|training accuracy -1.01224
# training session 828 	|training accuracy 2.54109
# training session 829 	|training accuracy 1.70767
# training session 830 	|training accuracy -1.81512
# training session 831 	|training accuracy -1.41013
# training session 832 	|training accuracy 1.33936
# training session 833 	|training accuracy 1.55655
# training session 834 	|training accuracy -0.878018
# training session 835 	|training accuracy -0.661142
# training session 836 	|training accuracy 2.6388
# training session 837 	|training accuracy 1.96745
# training session 838 	|training accuracy -2.74039
# training session 839 	|training accuracy -2.3054
# training session 840 	|training accuracy 1.87564
# training session 841 	|training accuracy 2.8323
# training session 842 	|training accuracy -1.02136
# training session 843 	|training accuracy -2.24401
# training session 844 	|training accuracy 1.75202
# training session 845 	|training accuracy 1.79393
# training session 846 	|training accuracy -2.45398
# training session 847 	|training accuracy -2.45603
# training session 848 	|training accuracy 2.20154
# training session 849 	|training accuracy 2.12778
# training session 850 	|training accuracy -2.64691
# training session 851 	|training accuracy -2.28362
# training session 852 	|training accuracy 3.43729
# training session 853 	|training accuracy 2.77809
# training session 854 	|training accuracy -1.90299
# training session 855 	|training accuracy -1.74925
# training session 856 	|training accuracy 2.38234
# training session 857 	|training accuracy 1.71973
# training session 858 	|training accuracy -2.38849
# training session 859 	|training accuracy -0.977997
# training session 860 	|training accuracy 2.78026
# training session 861 	|training accuracy 1.1271
# training session 862 	|training accuracy -1.81642
# training session 863 	|training accuracy -0.0775557
# training session 864 	|training accuracy 2.65134
# training session 865 	|training accuracy -0.00775126
# training session 866 	|training accuracy -1.85696
# training session 867 	|training accuracy 1.00048
# training session 868 	|training accuracy 2.42877
# training session 869 	|training accuracy -0.262909
# training session 870 	|training accuracy -2.1979
# training session 871 	|training accuracy -0.0996941
# training session 872 	|training accuracy 0.976602
# training session 873 	|training accuracy 0.714306
# training session 874 	|training accuracy -0.266891
# training session 875 	|training accuracy 0.450228
# training session 876 	|training accuracy 0.0498588
# training session 877 	|training accuracy -0.857244
# training session 878 	|training accuracy 1.43672
# training session 879 	|training accuracy 0.847623
# training session 880 	|training accuracy -2.30297
# training session 881 	|training accuracy 0.514368
# training session 882 	|training accuracy 2.79454
# training session 883 	|training accuracy -0.382145
# training session 884 	|training accuracy -3.32972
# training session 885 	|training accuracy -0.101054
# training session 886 	|training accuracy 4.29221
# training session 887 	|training accuracy 2.11947
# training session 888 	|training accuracy -1.75031
# training session 889 	|training accuracy -0.695802
# training session 890 	|training accuracy 1.80358
# training session 891 	|training accuracy 1.10733
# training session 892 	|training accuracy 0.76502
# training session 893 	|training accuracy -0.385342
# training session 894 	|training accuracy -1.63888
# training session 895 	|training accuracy -1.24186
# training session 896 	|training accuracy 2.07383
# training session 897 	|training accuracy 3.03088
# training session 898 	|training accuracy -0.948145
# training session 899 	|training accuracy -1.30303
# training session 900 	|training accuracy 1.37135
# training session 901 	|training accuracy 0.0791649
# training session 902 	|training accuracy -0.178194
# training session 903 	|training accuracy 0.684256
# training session 904 	|training accuracy -0.179142
# training session 905 	|training accuracy 0.541545
# training session 906 	|training accuracy 0.465519
# training session 907 	|training accuracy -0.129353
# training session 908 	|training accuracy 0.454635
# training session 909 	|training accuracy 0.387326
# training session 910 	|training accuracy 0.597437
# training session 911 	|training accuracy 0.378752
# training session 912 	|training accuracy -0.201613
# training session 913 	|training accuracy 0.987734
# training session 914 	|training accuracy -0.159573
# training session 915 	|training accuracy 0.757107
# training session 916 	|training accuracy -0.0842217
# training session 917 	|training accuracy -0.00470599
# training session 918 	|training accuracy -0.184054
# training session 919 	|training accuracy 0.499421
# training session 920 	|training accuracy 0.625356
# training session 921 	|training accuracy -0.307095
# training session 922 	|training accuracy -0.403685
# training session 923 	|training accuracy 1.20818
# training session 924 	|training accuracy 0.0292887
# training session 925 	|training accuracy -1.33604
# training session 926 	|training accuracy 1.41106
# training session 927 	|training accuracy 1.4512
# training session 928 	|training accuracy -1.96386
# training session 929 	|training accuracy -1.15633e-05
# training session 930 	|training accuracy 2.14079
# training session 931 	|training accuracy -0.63882
# training session 932 	|training accuracy -2.09801
# training session 933 	|training accuracy 0.951191
# training session 934 	|training accuracy 1.29636
# training session 935 	|training accuracy 0.253958
# training session 936 	|training accuracy -0.110742
# training session 937 	|training accuracy -0.45218
# training session 938 	|training accuracy -1.40076
# training session 939 	|training accuracy 0.618939
# training session 940 	|training accuracy 1.73408
# training session 941 	|training accuracy -0.0832278
# training session 942 	|training accuracy -0.993859
# training session 943 	|training accuracy 0.966467
# training session 944 	|training accuracy 1.78881
# training session 945 	|training accuracy -1.27041
# training session 946 	|training accuracy -1.80752
# training session 947 	|training accuracy 1.47128
# training session 948 	|training accuracy 1.55414
# training session 949 	|training accuracy -0.738607
# training session 950 	|training accuracy 0.322472
# training session 951 	|training accuracy 1.44999
# training session 952 	|training accuracy -0.0539679
# training session 953 	|training accuracy -0.288695
# training session 954 	|training accuracy -0.373353
# training session 955 	|training accuracy -0.101069
# training session 956 	|training accuracy 1.15432
# training session 957 	|training accuracy -0.377202
# training session 958 	|training accuracy -0.534533
# training session 959 	|training accuracy 0.560471
# training session 960 	|training accuracy 0.844526
# training session 961 	|training accuracy -0.799105
# training session 962 	|training accuracy 0.436803
# training session 963 	|training accuracy 1.20459
# training session 964 	|training accuracy -0.375585
# ...
# training session 9689 	|training accuracy -0.585667
# training session 9690 	|training accuracy -0.266414
# training session 9691 	|training accuracy 0.96422
# training session 9692 	|training accuracy -0.239667
# training session 9693 	|training accuracy -0.983179
# training session 9694 	|training accuracy 0.418445
# training session 9695 	|training accuracy 1.19127
# training session 9696 	|training accuracy -1.04829
# training session 9697 	|training accuracy -0.582482
# training session 9698 	|training accuracy 1.20245
# training session 9699 	|training accuracy 0.056006
# training session 9700 	|training accuracy -0.988003
# training session 9701 	|training accuracy 0.541863
# training session 9702 	|training accuracy 0.484809
# training session 9703 	|training accuracy -0.318938
# training session 9704 	|training accuracy 0.127755
# training session 9705 	|training accuracy 0.140678
# training session 9706 	|training accuracy -0.41953
# training session 9707 	|training accuracy 0.19618
# training session 9708 	|training accuracy 0.188145
# training session 9709 	|training accuracy -0.841628
# training session 9710 	|training accuracy 0.433925
# training session 9711 	|training accuracy 0.308545
# training session 9712 	|training accuracy -1.02157
# training session 9713 	|training accuracy 1.08825
# training session 9714 	|training accuracy 0.980386
# training session 9715 	|training accuracy -0.944254
# training session 9716 	|training accuracy -0.325054
# training session 9717 	|training accuracy 0.794862
# training session 9718 	|training accuracy -0.960938
# training session 9719 	|training accuracy -0.126788
# training session 9720 	|training accuracy 0.673414
# training session 9721 	|training accuracy -0.187396
# training session 9722 	|training accuracy -0.893472
# training session 9723 	|training accuracy 0.746018
# training session 9724 	|training accuracy 0.419671
# training session 9725 	|training accuracy -0.512185
# training session 9726 	|training accuracy 0.603714
# training session 9727 	|training accuracy 0.278493
# training session 9728 	|training accuracy -0.852156
# training session 9729 	|training accuracy -0.545748
# training session 9730 	|training accuracy 0.884117
# training session 9731 	|training accuracy 0.67721
# training session 9732 	|training accuracy -0.766802
# training session 9733 	|training accuracy -0.568914
# training session 9734 	|training accuracy 0.873387
# training session 9735 	|training accuracy 0.962612
# training session 9736 	|training accuracy -0.441828
# training session 9737 	|training accuracy -0.983847
# training session 9738 	|training accuracy 0.176149
# training session 9739 	|training accuracy 1.55969
# training session 9740 	|training accuracy 0.740082
# training session 9741 	|training accuracy -0.873146
# training session 9742 	|training accuracy -0.859813
# training session 9743 	|training accuracy 0.373902
# training session 9744 	|training accuracy 1.44652
# training session 9745 	|training accuracy 0.455945
# training session 9746 	|training accuracy -0.799597
# training session 9747 	|training accuracy -0.37278
# training session 9748 	|training accuracy 0.846568
# training session 9749 	|training accuracy -0.224085
# training session 9750 	|training accuracy -1.29432
# training session 9751 	|training accuracy -0.567105
# training session 9752 	|training accuracy 0.855404
# training session 9753 	|training accuracy 1.29665
# training session 9754 	|training accuracy -1.07162
# training session 9755 	|training accuracy -1.24202
# training session 9756 	|training accuracy 0.419873
# training session 9757 	|training accuracy 0.726647
# training session 9758 	|training accuracy -0.655003
# training session 9759 	|training accuracy -0.835952
# training session 9760 	|training accuracy 0.596452
# training session 9761 	|training accuracy 0.335234
# training session 9762 	|training accuracy 0.230406
# training session 9763 	|training accuracy -0.0224414
# training session 9764 	|training accuracy -0.436792
# training session 9765 	|training accuracy 0.314034
# training session 9766 	|training accuracy 1.09486
# training session 9767 	|training accuracy -0.767425
# training session 9768 	|training accuracy -0.644948
# training session 9769 	|training accuracy 0.545094
# training session 9770 	|training accuracy 0.757966
# training session 9771 	|training accuracy -1.40922
# training session 9772 	|training accuracy -0.752769
# training session 9773 	|training accuracy 0.923819
# training session 9774 	|training accuracy 0.683224
# training session 9775 	|training accuracy -0.260764
# training session 9776 	|training accuracy -1.18717
# training session 9777 	|training accuracy 0.0969684
# training session 9778 	|training accuracy 0.825003
# training session 9779 	|training accuracy -0.366875
# training session 9780 	|training accuracy -0.594498
# training session 9781 	|training accuracy 0.0938819
# training session 9782 	|training accuracy -0.144108
# training session 9783 	|training accuracy 0.750856
# training session 9784 	|training accuracy 0.156536
# training session 9785 	|training accuracy -0.513901
# training session 9786 	|training accuracy 0.276937
# training session 9787 	|training accuracy -0.0322218
# training session 9788 	|training accuracy -0.773892
# training session 9789 	|training accuracy 0.344946
# training session 9790 	|training accuracy 0.429173
# training session 9791 	|training accuracy -0.181503
# training session 9792 	|training accuracy -0.18275
# training session 9793 	|training accuracy -0.00989885
# training session 9794 	|training accuracy -0.0437005
# training session 9795 	|training accuracy -0.217007
# training session 9796 	|training accuracy 0.741639
# training session 9797 	|training accuracy -0.535345
# training session 9798 	|training accuracy -0.160318
# training session 9799 	|training accuracy 0.498395
# training session 9800 	|training accuracy -0.41685
# training session 9801 	|training accuracy -0.681229
# training session 9802 	|training accuracy 0.915448
# training session 9803 	|training accuracy 0.328645
# training session 9804 	|training accuracy -1.40053
# training session 9805 	|training accuracy 0.0881711
# training session 9806 	|training accuracy 1.23168
# training session 9807 	|training accuracy -0.0185513
# training session 9808 	|training accuracy -0.81484
# training session 9809 	|training accuracy 0.0312652
# training session 9810 	|training accuracy 0.220507
# training session 9811 	|training accuracy 0.202977
# training session 9812 	|training accuracy 0.133601
# training session 9813 	|training accuracy -0.266847
# training session 9814 	|training accuracy -0.344005
# training session 9815 	|training accuracy 0.249635
# training session 9816 	|training accuracy 1.49215
# training session 9817 	|training accuracy 0.118358
# training session 9818 	|training accuracy -1.40702
# training session 9819 	|training accuracy -0.243325
# training session 9820 	|training accuracy 1.23299
# training session 9821 	|training accuracy -0.278909
# training session 9822 	|training accuracy -1.72916
# training session 9823 	|training accuracy 0.180074
# training session 9824 	|training accuracy 1.48484
# training session 9825 	|training accuracy 0.169313
# training session 9826 	|training accuracy -1.36167
# training session 9827 	|training accuracy 0.124855
# training session 9828 	|training accuracy 1.09616
# training session 9829 	|training accuracy -0.103841
# training session 9830 	|training accuracy -1.22445
# training session 9831 	|training accuracy 0.696348
# training session 9832 	|training accuracy 1.37396
# training session 9833 	|training accuracy -0.746705
# training session 9834 	|training accuracy -1.35371
# training session 9835 	|training accuracy 1.00542
# training session 9836 	|training accuracy 1.40781
# training session 9837 	|training accuracy -0.430599
# training session 9838 	|training accuracy -1.36228
# training session 9839 	|training accuracy 0.33916
# training session 9840 	|training accuracy 1.43286
# training session 9841 	|training accuracy -0.100501
# training session 9842 	|training accuracy -1.20003
# training session 9843 	|training accuracy -0.23534
# training session 9844 	|training accuracy 0.924431
# training session 9845 	|training accuracy 0.190659
# training session 9846 	|training accuracy -0.319062
# training session 9847 	|training accuracy 0.414445
# training session 9848 	|training accuracy 0.735091
# training session 9849 	|training accuracy -0.658456
# training session 9850 	|training accuracy -0.326243
# training session 9851 	|training accuracy 1.19571
# training session 9852 	|training accuracy 0.0943758
# training session 9853 	|training accuracy -0.90667
# training session 9854 	|training accuracy 0.578767
# training session 9855 	|training accuracy 0.861853
# training session 9856 	|training accuracy -0.751832
# training session 9857 	|training accuracy -0.731715
# training session 9858 	|training accuracy 0.887203
# training session 9859 	|training accuracy 0.199985
# training session 9860 	|training accuracy -0.968429
# training session 9861 	|training accuracy 0.393826
# training session 9862 	|training accuracy 0.298831
# training session 9863 	|training accuracy -0.510338
# training session 9864 	|training accuracy 0.0615591
# training session 9865 	|training accuracy 0.0337736
# training session 9866 	|training accuracy -0.173634
# training session 9867 	|training accuracy 0.496898
# training session 9868 	|training accuracy 0.443882
# training session 9869 	|training accuracy -0.520236
# training session 9870 	|training accuracy -0.755451
# training session 9871 	|training accuracy 1.24968
# training session 9872 	|training accuracy 1.21709
# training session 9873 	|training accuracy -0.355127
# training session 9874 	|training accuracy -0.398951
# training session 9875 	|training accuracy 0.572557
# training session 9876 	|training accuracy 0.309803
# training session 9877 	|training accuracy -0.919408
# training session 9878 	|training accuracy 0.0590369
# training session 9879 	|training accuracy 0.690784
# training session 9880 	|training accuracy -0.577924
# training session 9881 	|training accuracy -0.809505
# training session 9882 	|training accuracy 0.830582
# training session 9883 	|training accuracy 0.540632
# training session 9884 	|training accuracy -1.16106
# training session 9885 	|training accuracy -0.0676444
# training session 9886 	|training accuracy 1.17431
# training session 9887 	|training accuracy -0.213713
# training session 9888 	|training accuracy -0.950709
# training session 9889 	|training accuracy 1.11544
# training session 9890 	|training accuracy 0.932393
# training session 9891 	|training accuracy -1.34556
# training session 9892 	|training accuracy -0.836986
# training session 9893 	|training accuracy 1.71015
# training session 9894 	|training accuracy 0.758269
# training session 9895 	|training accuracy -1.40331
# training session 9896 	|training accuracy -0.582094
# training session 9897 	|training accuracy 0.809596
# training session 9898 	|training accuracy -0.521592
# training session 9899 	|training accuracy -0.673397
# training session 9900 	|training accuracy 0.900986
# training session 9901 	|training accuracy 0.29081
# training session 9902 	|training accuracy -1.21661
# training session 9903 	|training accuracy 0.10787
# training session 9904 	|training accuracy 1.13898
# training session 9905 	|training accuracy -0.469456
# training session 9906 	|training accuracy -1.14622
# training session 9907 	|training accuracy 0.704021
# training session 9908 	|training accuracy 0.851822
# training session 9909 	|training accuracy -1.38769
# training session 9910 	|training accuracy -0.612269
# training session 9911 	|training accuracy 1.68001
# training session 9912 	|training accuracy 0.797027
# training session 9913 	|training accuracy -1.70767
# training session 9914 	|training accuracy -0.61486
# training session 9915 	|training accuracy 1.57967
# training session 9916 	|training accuracy 0.45873
# training session 9917 	|training accuracy -1.46265
# training session 9918 	|training accuracy -0.233703
# training session 9919 	|training accuracy 1.15958
# training session 9920 	|training accuracy -0.0726207
# training session 9921 	|training accuracy -0.721787
# training session 9922 	|training accuracy -0.149522
# training session 9923 	|training accuracy 0.593606
# training session 9924 	|training accuracy -0.235133
# training session 9925 	|training accuracy 0.250437
# training session 9926 	|training accuracy 0.279387
# training session 9927 	|training accuracy -0.634354
# training session 9928 	|training accuracy 0.428273
# training session 9929 	|training accuracy 0.442074
# training session 9930 	|training accuracy -0.692737
# training session 9931 	|training accuracy -0.756536
# training session 9932 	|training accuracy 0.579575
# training session 9933 	|training accuracy 0.264838
# training session 9934 	|training accuracy -0.00896426
# training session 9935 	|training accuracy 0.198014
# training session 9936 	|training accuracy -0.119706
# training session 9937 	|training accuracy 0.01533
# training session 9938 	|training accuracy 0.478263
# training session 9939 	|training accuracy 0.342206
# training session 9940 	|training accuracy -0.728869
# training session 9941 	|training accuracy -0.00457035
# training session 9942 	|training accuracy 0.336976
# training session 9943 	|training accuracy 0.278766
# training session 9944 	|training accuracy -0.346468
# training session 9945 	|training accuracy 0.0850807
# training session 9946 	|training accuracy 0.332152
# training session 9947 	|training accuracy 0.038376
# training session 9948 	|training accuracy -0.458723
# training session 9949 	|training accuracy 0.436189
# training session 9950 	|training accuracy 0.51183
# training session 9951 	|training accuracy -0.831333
# training session 9952 	|training accuracy 0.0714646
# training session 9953 	|training accuracy -0.0252078
# training session 9954 	|training accuracy -0.206174
# training session 9955 	|training accuracy 0.213374
# training session 9956 	|training accuracy -0.481836
# training session 9957 	|training accuracy -0.172036
# training session 9958 	|training accuracy 0.227106
# training session 9959 	|training accuracy -0.424469
# training session 9960 	|training accuracy 0.281536
# training session 9961 	|training accuracy 0.364512
# training session 9962 	|training accuracy -0.771478
# training session 9963 	|training accuracy -0.167156
# training session 9964 	|training accuracy 1.11806
# training session 9965 	|training accuracy -0.288813
# training session 9966 	|training accuracy -0.949316
# training session 9967 	|training accuracy 0.456999
# training session 9968 	|training accuracy 0.148724
# training session 9969 	|training accuracy -0.594979
# training session 9970 	|training accuracy 0.700649
# training session 9971 	|training accuracy 0.324195
# training session 9972 	|training accuracy -1.11494
# training session 9973 	|training accuracy -0.134842
# training session 9974 	|training accuracy 1.35746
# training session 9975 	|training accuracy -0.522981
# training session 9976 	|training accuracy -1.38379
# training session 9977 	|training accuracy 0.722342
# training session 9978 	|training accuracy 0.754992
# training session 9979 	|training accuracy -1.24145
# training session 9980 	|training accuracy -0.603028
# training session 9981 	|training accuracy 1.81907
# training session 9982 	|training accuracy 1.25359
# training session 9983 	|training accuracy -1.4991
# training session 9984 	|training accuracy -1.67322
# training session 9985 	|training accuracy 0.89868
# training session 9986 	|training accuracy 1.33116
# training session 9987 	|training accuracy -0.1288
# training session 9988 	|training accuracy -1.116
# training session 9989 	|training accuracy 0.472101
# training session 9990 	|training accuracy 0.998882
# training session 9991 	|training accuracy -0.453955
# training session 9992 	|training accuracy -0.847482
# training session 9993 	|training accuracy 0.588212
# training session 9994 	|training accuracy 0.778523
# training session 9995 	|training accuracy -0.962316
# training session 9996 	|training accuracy -0.540795
# training session 9997 	|training accuracy 1.19882
# training session 9998 	|training accuracy -0.210723
# training session 9999 	|training accuracy -0.638288

# %%
predictions = y2
eval_predictions = predictions.eval(feed_dict={x: allX, keep_prob: 1.}, session=sess)

# %%
quarterly_data_pred = quarterly_data.with_column("Predictions", np.append(np.zeros(39), eval_predictions))

quarterly_pred_w_time = quarterly_data_pred.select("OUTPUT MINUS POTENTIAL", "Predictions").with_column("DATE", [int(x[:len(x) - 3]) + int(x[len(x) - 2:])/12 for x in quarterly_data.column("DATE")])
quarterly_pred_w_time.plot("DATE", width = 30, height = 18)

# %%
quarterly_pred_w_time.where("DATE", are.between(1999, 2018)).plot("DATE", width = 30, height = 18)
